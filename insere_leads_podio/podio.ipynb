# %%
# %load_ext autoreload
# %load_ext dotenv
# %autoreload
# %dotenv ../.env
from selenium.webdriver.common.by import By
from time import sleep
import re
import glob
import os
import json
import pandas as pd
from io import StringIO
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9014")
driver = webdriver.Chrome(options=chrome_options)
DOWNLOAD_FOLDER = '../downloads'
title = current = button = paginator = page_els = ''
nome_atual = ''

def sel(selector, el=None):
    if el:
        return el.find_element(By.CSS_SELECTOR, selector)
    return driver.find_element(By.CSS_SELECTOR, selector)

def sels(selector, el=None):
    if el:
        return el.find_elements(By.CSS_SELECTOR, selector)
    return driver.find_elements(By.CSS_SELECTOR, selector)

def clicar(el):
    webdriver.ActionChains(driver).move_to_element(el).click(el).perform()

def start():
    driver.get(os.getenv("URL_PODIO"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
start()

# %%
def scroll_to_reveal_data():
    el_mostra_leads = sel('ul.app-filter-tools li.app-view-tools__item.count.app-view-count.items-counter')
    quantidade_leads = str(el_mostra_leads.text.split('de')[0].strip())
    atual = str(sels('.app-wrapper__content table.count tr')[-1].text.strip())
    while atual != quantidade_leads:
        sel('body').send_keys(Keys.END)
        sleep(2.5)
        atual = sels('.app-wrapper__content table.count tr')[-1].text.strip()
scroll_to_reveal_data()

# %%
def get_inner_data():
    trs = sels('section.app-view__content main tbody.content tr')
    ths = sels('section.app-view__content main table.data thead th')
    csv = '\t'.join([th.text.strip() for th in ths]) + '\n'
    for i, tr in enumerate(trs):
        tds = sels('td', tr)
        print(f'{i}/{len(trs)}/{len(tds)}')
        csv += '\t'.join([td.text for td in tds]) + '\n'
    return csv
csv = get_inner_data()
# Out:
# 0/746/34
# 1/746/34
# 2/746/34
# 3/746/34
# 4/746/34
# 5/746/34
# 6/746/34
# 7/746/34
# 8/746/34
# 9/746/34
# 10/746/34
# 11/746/34
# 12/746/34
# 13/746/34
# 14/746/34
# 15/746/34
# 16/746/34
# 17/746/34
# 18/746/34
# 19/746/34
# 20/746/34
# 21/746/34
# 22/746/34
# 23/746/34
# 24/746/34
# 25/746/34
# 26/746/34
# 27/746/34
# 28/746/34
# 29/746/34
# 30/746/34
# 31/746/34
# 32/746/34
# 33/746/34
# 34/746/34
# 35/746/34
# 36/746/34
# 37/746/34
# 38/746/34
# 39/746/34
# 40/746/34
# 41/746/34
# 42/746/34
# 43/746/34
# 44/746/34
# 45/746/34
# 46/746/34
# 47/746/34
# 48/746/34
# 49/746/34
# 50/746/34
# 51/746/34
# 52/746/34
# 53/746/34
# 54/746/34
# 55/746/34
# 56/746/34
# 57/746/34
# 58/746/34
# 59/746/34
# 60/746/34
# 61/746/34
# 62/746/34
# 63/746/34
# 64/746/34
# 65/746/34
# 66/746/34
# 67/746/34
# 68/746/34
# 69/746/34
# 70/746/34
# 71/746/34
# 72/746/34
# 73/746/34
# 74/746/34
# 75/746/34
# 76/746/34
# 77/746/34
# 78/746/34
# 79/746/34
# 80/746/34
# 81/746/34
# 82/746/34
# 83/746/34
# 84/746/34
# 85/746/34
# 86/746/34
# 87/746/34
# 88/746/34
# 673/746/34
# 674/746/34
# 675/746/34
# 676/746/34
# 677/746/34
# 678/746/34
# 679/746/34
# 680/746/34
# 681/746/34
# 682/746/34
# 683/746/34
# 684/746/34
# 685/746/34
# 686/746/34
# 687/746/34
# 688/746/34
# 689/746/34
# 690/746/34
# 691/746/34
# 692/746/34
# 693/746/34
# 694/746/34
# 695/746/34
# 696/746/34
# 697/746/34
# 698/746/34
# 699/746/34
# 700/746/34
# 701/746/34
# 702/746/34
# 703/746/34
# 704/746/34
# 705/746/34
# 706/746/34
# 707/746/34
# 708/746/34
# 709/746/34
# 710/746/34
# 711/746/34
# 712/746/34
# 713/746/34
# 714/746/34
# 715/746/34
# 716/746/34
# 717/746/34
# 718/746/34
# 719/746/34
# 720/746/34
# 721/746/34
# 722/746/34
# 723/746/34
# 724/746/34
# 725/746/34
# 726/746/34
# 727/746/34
# 728/746/34
# 729/746/34
# 730/746/34
# 731/746/34
# 732/746/34
# 733/746/34
# 734/746/34
# 735/746/34
# 736/746/34
# 737/746/34
# 738/746/34
# 739/746/34
# 740/746/34
# 741/746/34
# 742/746/34
# 743/746/34
# 744/746/34
# 745/746/34

# %%
import pandas as pd
from io import StringIO

df_podio = pd.read_csv(StringIO(csv), sep='\t').reset_index(drop=True)

# %%
import re

data = """
0                   manoelamallet@gmail.com (Casa)
1              amanda.bsantos2000@gmail.com (Casa)
2                 viclaranjeira@hotmail.com (Casa)
3                    eloy.lucas94@gmail.com (Casa)
4      maiaralohmann2025@u.northwestern.edu (Casa)
"""

email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

emails = re.findall(email_pattern, data)

for email in emails:
    print(email)
# Out:
# manoelamallet@gmail.com
# amanda.bsantos2000@gmail.com
# viclaranjeira@hotmail.com
# eloy.lucas94@gmail.com
# maiaralohmann2025@u.northwestern.edu

# %%
df_podio['Email']
# Out:
# 0                   manoelamallet@gmail.com (Casa)
# 1              amanda.bsantos2000@gmail.com (Casa)
# 2                 viclaranjeira@hotmail.com (Casa)
# 3                    eloy.lucas94@gmail.com (Casa)
# 4      maiaralohmann2025@u.northwestern.edu (Casa)
#                           ...
# 741             talythasoares0701@gmail.com (Casa)
# 742                   amanrinaldi@gmail.com (Casa)
# 743            carlaescobar2004@outlook.com (Casa)
# 744              Jaquelinef_silva@yahoo.com (Casa)
# 745          robson.fermino.silva@gmail.com (Casa)
# Name: Email, Length: 746, dtype: object

# %%
import re
df_podio['Email Limpo'] = df_podio['Email'].apply(lambda x: '' if not (found := re.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b', x)) else found[0])
# df_podio[df_podio['Email Limpo'] == '']

# %%
# df.head()
df_podio.to_excel('2023-06-11-03-07.xlsx')

# %%
import json
with open('linkas.json', encoding='utf-8') as f:
    _dict = json.load(f)
driver.get(os.getenv('URL_BUILDER'))

# %%
# Beatriz vecino
def treat(str_value: str) -> str:
    return str_value.lower().strip()
df_pessoas = pd.DataFrame(_dict.values(), columns=_dict['1'].keys()).drop_duplicates('email')
df_pessoas_novas_by_email = df_pessoas[~df_pessoas['email'].apply(treat).isin(df_podio['Email Limpo'].apply(treat))]
df_pessoas_novas_by_name = df_pessoas[~df_pessoas['nome_completo'].apply(treat).isin(df_podio['Nome'].apply(treat))]
df_intersection = df_pessoas_novas_by_email[~df_pessoas_novas_by_email['email'].isin(df_pessoas_novas_by_name['email'])]

# %%
len(df_pessoas_novas_by_email), len(df_pessoas_novas_by_name)
# Out:
# (79, 75)

# %%
len(df_pessoas_novas_by_email), len(df_pessoas_novas_by_name), len(df_intersection), len(df_pessoas_novas_by_email.drop_duplicates('nome_completo'))
df_merge = pd.merge(left=df_pessoas_novas_by_email, right=df_pessoas_novas_by_name, on=['nome_completo'], how='outer')
df_atualizar_email = df_merge[df_merge['email_y'].isna()]
df_podio_email_errado = df_podio[df_podio['Nome'].isin(df_atualizar_email['nome_completo'])]
df_atualizar_email
# Out:
#          nome_completo                       email_x   telefone_x  \
# 0      Vitória Barbara   vitoriabarbara278@gmail.com           83
# 1     Carolina Rossini  carolinasrossini@hotmail.com  11964766505
# 2  Christiano Ferreira     chrisfer.vilela@gmail.com  31991955415
# 3           Laura Mota      laurammotinhaa@gmail.com  11943057502
# 4        Thomas Xavier              thogxf@gmail.com  11982260857
# 5         Amanda Diniz         adiniz00000@gmail.com  11964627516
#
#                             curriculo_x       inglês_x  \
# 0      ../downloads/007_Vitória_Barbara        fluente
# 1     ../downloads/011_Carolina_Rossini       avançado
# 2  ../downloads/013_Christiano_Ferreira  intermediário
# 3           ../downloads/016_Laura_Mota       avançado
# 4        ../downloads/020_Thomas_Xavier       avançado
# 5         ../downloads/027_Amanda_Diniz  intermediário
#
#                                               link_x email_y telefone_y  \
# 0  https://www.linkedin.com/in/vit%C3%B3ria-barba...     NaN        NaN
# 1      https://www.linkedin.com/in/carolinasrossini/     NaN        NaN
# 2  https://www.linkedin.com/in/christiano-ferreir...     NaN        NaN
# 3  https://www.linkedin.com/in/laura-mota-8158b6234/     NaN        NaN
# 4  https://www.linkedin.com/in/thomas-xavier-ferr...     NaN        NaN
# 5  https://www.linkedin.com/in/amanda-diniz-3aa3a...     NaN        NaN
#
#   curriculo_y inglês_y link_y
# 0         NaN      NaN    NaN
# 1         NaN      NaN    NaN
# 2         NaN      NaN    NaN
# 3         NaN      NaN    NaN
# 4         NaN      NaN    NaN
# 5         NaN      NaN    NaN

# %%
df_merge_inner = pd.merge(left=df_pessoas_novas_by_email, right=df_pessoas_novas_by_name, on=['nome_completo', 'email'])
df_merge_inner.columns = df_merge_inner.columns.str.replace(r'_[xy]$', '', regex=True)
df_pessoas_novas = df_merge_inner.loc[:, ~df_merge_inner.columns.duplicated()]
df_pessoas_novas
# Out:
#            nome_completo                            email      telefone  \
# 0              Yasmin R.               ruivoyas@gmail.com   11934010041
# 1    Guilherme Rodrigues      fhod74rodrigues@hotmail.com   11930761188
# 2            Milena Reis  milenachristiesantana@gmail.com   11975238589
# 3          Larissa Veiga       larissamotta22@hotmail.com   71991713728
# 4   Isabella Marin Silva        isabellamarinsilva@usp.br   14997466775
# ..                   ...                              ...           ...
# 68         Emily Curbani          emilycurbani1@gmail.com   41984053956
# 69    Guilherme Carvalho   guilhermetcarvalho08@gmail.com   11998816291
# 70         Renan Corazza         renancorazza.c@gmail.com   11981308804
# 71        Bianca Almeida              bia.acc15@gmail.com   71981788584
# 72          Paloma Bueno          palomabuenori@gmail.com  119332123350
#
#                                 curriculo         inglês  \
# 0              ../downloads/031_Yasmin_R.        fluente
# 1    ../downloads/038_Guilherme_Rodrigues       avançado
# 2            ../downloads/043_Milena_Reis  intermediário
# 3          ../downloads/045_Larissa_Veiga  intermediário
# 4   ../downloads/049_Isabella_Marin_Silva       avançado
# ..                                    ...            ...
# 68         ../downloads/121_Emily_Curbani       avançado
# 69    ../downloads/122_Guilherme_Carvalho        fluente
# 70         ../downloads/123_Renan_Corazza       avançado
# 71        ../downloads/124_Bianca_Almeida       avançado
# 72          ../downloads/125_Paloma_Bueno  intermediário
#
#                                                  link
# 0     https://www.linkedin.com/in/yasmin-r-3b5926211/
# 1   https://www.linkedin.com/in/guilherme-rodrigue...
# 2   https://www.linkedin.com/in/milena-reis-40727b...
# 3      https://www.linkedin.com/in/larissa-veiga2210/
# 4   https://www.linkedin.com/in/isabella-marin-sil...
# ..                                                ...
# 68          https://www.linkedin.com/in/emilycurbani/
# 69    https://www.linkedin.com/in/guilhermetcarvalho/
# 70  https://www.linkedin.com/in/renan-corazza-25b2...
# 71  https://www.linkedin.com/in/bianca-almeida-bb6...
# 72  https://www.linkedin.com/in/paloma-bueno-bb742...
#
# [73 rows x 6 columns]

# %%
df_podio[df_podio['Nome'].isin(df_merge[df_merge['email_y'].isna()]['nome_completo'])]
# Out:
#                     Nome    Data inscrição         produto  \
# 113  Christiano Ferreira  17/04/2023 14:02  Talento Global
# 116           Laura Mota  17/04/2023 13:30  Talento Global
# 120        Thomas Xavier  17/04/2023 13:27  Talento Global
# 128         Amanda Diniz  17/04/2023 13:23  Talento Global
# 139     Carolina Rossini  17/04/2023 12:48  Talento Global
# 146      Vitória Barbara  16/04/2023 21:53  Talento Global
#
#                       Duracao Data de nascimento [EXPA] EP ID  \
# 113  3 a 18 meses - Programa…
# 116  6 a 8 semanas - Program…
# 120  3 a 18 meses - Programa…
# 128  6 a 8 semanas - Program…
# 139  3 a 18 meses - Programa…
# 146  3 a 18 meses - Programa…
#
#                                     Email            Telefone  \
# 113     chrisfer.vilelaa@gmail.com (Casa)  31991955415 (Casa)
# 116      laurammotinhaaa@gmail.com (Casa)  11943057502 (Casa)
# 120              thogxff@gmail.com (Casa)  11982260857 (Casa)
# 128         adiniz000000@gmail.com (Casa)  11964627516 (Casa)
# 139  carolinasrossinii@hotmail.com (Casa)  11964766505 (Casa)
# 146   vitoriabarbara2788@gmail.com (Casa)  83988566387 (Casa)
#
#              [INTERNO] Status Realocação  ... Process Time  \
# 113  Consultoria online feita             ...
# 116                  Abordado             ...
# 120                  Abordado             ...
# 128                  Abordado             ...
# 139                  Abordado             ...
# 146                  Abordado             ...
#
#     [EXPA] Application ID 1 tag-origem tag-conteudo      tag-meio  \
# 113
# 116                           linkedin
# 120                           linkedin
# 128                           linkedin
# 139                           linkedin        todos  texto-imagem
# 146                           linkedin
#
#     universidade gostaria-de-ser-contactado-por-celular Interno  \
# 113                                                 Sim     Sim
# 116                                                 Sim     Não
# 120                                                 Sim     Não
# 128                                                 Sim     Não
# 139                                                 Sim     Não
# 146                                                 Sim     Não
#
#     Anos Experiencia                    Email Limpo
# 113        Ainda não     chrisfer.vilelaa@gmail.com
# 116        Ainda não      laurammotinhaaa@gmail.com
# 120        Ainda não              thogxff@gmail.com
# 128        Ainda não         adiniz000000@gmail.com
# 139        Ainda não  carolinasrossinii@hotmail.com
# 146        Ainda não   vitoriabarbara2788@gmail.com
#
# [6 rows x 34 columns]

# %%
from selenium.webdriver.support.ui import Select
from selenium.webdriver.remote.webelement import WebElement

el_programa = sel('form > div > div:nth-child(1) .desktop select')
el_nome = sel('form > div > div:nth-child(2)  input.desktop')
el_celular = sel('form > div > div:nth-child(3)  input.desktop')
el_email = sel('form > div > div:nth-child(4)  input.desktop')
el_cl = sel('form > div > div:nth-child(5) input')
el_duracao = sel('form > div > div:nth-child(6) .desktop select')
el_form = sel('form')

def input_field(el: WebElement, value):
    el.clear()
    el.send_keys(value)

def select_option(el: WebElement, visible_text: str = None, num_opc: int=None, value_str: str = None):
    if not any((num_opc, visible_text, value_str)):
        raise ValueError('Inform at least one way of choosing')
    select = Select(el)
    if visible_text:
        select.select_by_visible_text(visible_text)
        return
    if num_opc:
        select.select_by_index(num_opc)
        return
    select.select_by_value(value_str)

select_option(el_programa, 'Talento Global')
input_field(el_nome, df_pessoas_novas['nome_completo'].iloc[4])
input_field(el_celular, df_pessoas_novas['telefone'].iloc[4])
input_field(el_email, df_pessoas_novas['email'].iloc[4])
input_field(el_cl, 'SAO PAULO - UNIDADE FGV (Bela Vista)')
select_option(el_duracao, 'Duração de 3 a 18 meses')

# %%
df_pessoas_novas
# Out:
#            nome_completo                            email      telefone  \
# 0              Yasmin R.               ruivoyas@gmail.com   11934010041
# 1    Guilherme Rodrigues      fhod74rodrigues@hotmail.com   11930761188
# 2            Milena Reis  milenachristiesantana@gmail.com   11975238589
# 3          Larissa Veiga       larissamotta22@hotmail.com   71991713728
# 4   Isabella Marin Silva        isabellamarinsilva@usp.br   14997466775
# ..                   ...                              ...           ...
# 68         Emily Curbani          emilycurbani1@gmail.com   41984053956
# 69    Guilherme Carvalho   guilhermetcarvalho08@gmail.com   11998816291
# 70         Renan Corazza         renancorazza.c@gmail.com   11981308804
# 71        Bianca Almeida              bia.acc15@gmail.com   71981788584
# 72          Paloma Bueno          palomabuenori@gmail.com  119332123350
#
#                                 curriculo         inglês  \
# 0              ../downloads/031_Yasmin_R.        fluente
# 1    ../downloads/038_Guilherme_Rodrigues       avançado
# 2            ../downloads/043_Milena_Reis  intermediário
# 3          ../downloads/045_Larissa_Veiga  intermediário
# 4   ../downloads/049_Isabella_Marin_Silva       avançado
# ..                                    ...            ...
# 68         ../downloads/121_Emily_Curbani       avançado
# 69    ../downloads/122_Guilherme_Carvalho        fluente
# 70         ../downloads/123_Renan_Corazza       avançado
# 71        ../downloads/124_Bianca_Almeida       avançado
# 72          ../downloads/125_Paloma_Bueno  intermediário
#
#                                                  link
# 0     https://www.linkedin.com/in/yasmin-r-3b5926211/
# 1   https://www.linkedin.com/in/guilherme-rodrigue...
# 2   https://www.linkedin.com/in/milena-reis-40727b...
# 3      https://www.linkedin.com/in/larissa-veiga2210/
# 4   https://www.linkedin.com/in/isabella-marin-sil...
# ..                                                ...
# 68          https://www.linkedin.com/in/emilycurbani/
# 69    https://www.linkedin.com/in/guilhermetcarvalho/
# 70  https://www.linkedin.com/in/renan-corazza-25b2...
# 71  https://www.linkedin.com/in/bianca-almeida-bb6...
# 72  https://www.linkedin.com/in/paloma-bueno-bb742...
#
# [73 rows x 6 columns]

# %%
try:
    df_ja_existiam
except NameError:
    print('refazendo df_ja_existiam')
    df_ja_existiam = pd.DataFrame(columns=df_pessoas.columns)
try:
    df_inseridos
except NameError:
    print('refazendo df_inseridos')
    df_inseridos = pd.DataFrame(columns=df_pessoas.columns)

# Force reset
# df_ja_existiam = df_inseridos = pd.DataFrame(columns=df_pessoas.columns)
display(df_ja_existiam)
df_inseridos
# Out:
# Empty DataFrame
# Columns: [nome_completo, email, telefone, curriculo, inglês, link]
# Index: []
# Empty DataFrame
# Columns: [nome_completo, email, telefone, curriculo, inglês, link]
# Index: []

# %%
# display(df_pessoas_novas.to_markdown())
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(df_pessoas_novas)
wrong_phone = df_pessoas_novas[df_pessoas_novas['telefone'].apply(lambda x: (len(x) < 6) or ('+' in x))][['telefone', 'nome_completo', 'curriculo']]
# print(wrong_phone.to_markdown())
wrong_phone
# Out:
# Empty DataFrame
# Columns: [telefone, nome_completo, curriculo]
# Index: []

# %%
import os

folder_path = '../downloads/'
files = os.listdir(folder_path)

[f for f in files if any([name in f.replace('_', ' ').lower() for name in wrong_phone['nome_completo'].apply(lambda x: x.replace('_',' ').lower())])]
# Out:
# []

# %%
chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9014")
driver = webdriver.Chrome(options=chrome_options)

# %%
from selenium.webdriver.common.action_chains import ActionChains

def insert_in_podio(df_pessoas: pd.DataFrame):
    df_pessoas = df_pessoas[~df_pessoas['nome_completo'].isin(df_ja_existiam['nome_completo'])][~df_pessoas['nome_completo'].isin(df_inseridos['nome_completo'])]
    
    driver.get(os.getenv('URL_BUILDER'))
    for i, pessoa in df_pessoas.iterrows():
        el_programa = sel('form > div > div:nth-child(1) .desktop select')
        el_nome = sel('form > div > div:nth-child(2)  input.desktop')
        el_celular = sel('form > div > div:nth-child(3)  input.desktop')
        el_email = sel('form > div > div:nth-child(4)  input.desktop')
        el_cl = sel('form > div > div:nth-child(5) input')
        el_duracao = sel('form > div > div:nth-child(6) .desktop select')
        # el_form = sel('form')
        
        select_option(el_programa, 'Talento Global')
        input_field(el_nome, pessoa['nome_completo'])
        input_field(el_celular, pessoa['telefone'])
        input_field(el_email, pessoa['email'])
        input_field(el_cl, 'SAO PAULO - UNIDADE FGV (Bela Vista)')
        sleep(1)
        sel('li').click()
        sleep(1)
        # to_click_el = sel('.ui-1autocomplete-items li')
        # ActionChains(driver).move_to_element(to_click_el).click(to_click_el).perform()
        
        select_option(el_duracao, 'Duração de 3 a 18 meses')
        if len(sels('[role="alert"]')) != 0:
            # df_ja_existiam = df_ja_existiam.append(pessoa, ignore_index=True)
            df_ja_existiam.loc[len(df_ja_existiam)] = pessoa
            print(f"{pessoa['nome_completo']} {pessoa['email']} já está cadastrada")
            continue
        # df_inseridos = df_inseridos.append(pessoa, ignore_index=True)
        df_inseridos.loc[len(df_inseridos)] = pessoa
        sleep(1)
        # el_form.submit()
        sel('button').click()
        print(f"{pessoa['nome_completo']} {pessoa['email']} inserida")
        sleep(2)
        driver.get(os.getenv('URL_BUILDER'))
        sleep(8)
    sleep(5)
insert_in_podio(df_pessoas_novas)
# Out:
# C:\Users\xgabr\AppData\Local\Temp\ipykernel_23172\2047787520.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_pessoas = df_pessoas[~df_pessoas['nome_completo'].isin(df_ja_existiam['nome_completo'])][~df_pessoas['nome_completo'].isin(df_inseridos['nome_completo'])]
# Mayara Barbosa mayharabarbosa@live.com inserida
# Natalia Fernandes nataliafernandes28@outlook.com.br já está cadastrada
# Sophia Mendes sophialorenams@gmail.com já está cadastrada
# Ana Luiza De Nigris Garritano analuhgarritano@gmail.com inserida
# Caroline Alcantara carolinedalcantara@gmail.com inserida
# Camilly Vitória camillyvitoria763@gmail.com inserida
# Lorhan Rolemberg lorhan.rolemberg@gmail.com inserida
# Nicolas Oliveira Leclercq nicolasoleclercq@gmail.com inserida
# Carolina Cagni carolcagni@gmail.com já está cadastrada
# Guilherme Delarmelina Costa gdelarmelina@gmail.com inserida
# Fernanda Regiani de Deus fernandardeus@outlook.com inserida
# Sérgio Diniz sergiodiniz.sd26@gmail.com já está cadastrada
# Amanda Sandoval sandoval.amanda@hotmail.com já está cadastrada
# Larissa Luz larimidialuz@gmail.com inserida
# Anna Carrijo anna.carrijo@hotmail.com inserida
# Leonardo Cavazana Nunez leonunez1701@gmail.com inserida
# Felipe Fantato felipe.fantato3@gmail.com inserida
# Giulia Duprat giuliaduprat@michaelpage.com.br inserida
# Gabriela de Oliveira Lima gabi.oliverlima@outlook.com inserida
# Nathalia Lima nathmalii05@gmail.com inserida
# Luis Oliveira guocambraia@hotmail.com inserida
# Beatriz Lima belima554@gmail.com já está cadastrada
# João Vitor Santos jvitor053@gmail.com já está cadastrada
# Lívia Martins liviamxrtins@gmail.com já está cadastrada
# Giulia Giordano Luchiari giuluchiari@gmail.com inserida
# Carolina Toledo carolinatoledodonascimento@gmail.com inserida
# Juliana Akemi ju.uchida@icloud.com inserida
# Igor Florindo igorflorindocarvalho@hotmail.com já está cadastrada
# Bernardo Marques bernardo.marques02@outlook.com já está cadastrada
# Julia Lopes juliaplopes@yahoo.com já está cadastrada
# Gabrielle Midory midorygabrielle@gmail.com inserida
# Isabela Macedo isabelamacedo858@gmail.com inserida
# Giovanna Castro de Melo giovannacastrodem@gmail.com inserida
# Adriana Ferreira adrianalaisseferreira@gmail.com inserida
# Pedro Chiurco pechiurco@gmail.com inserida
# Luna Lopes lunalopesvieira@outlook.com inserida
# Daniel Tardoqui tardoqui1997@gmail.com inserida
# Nathalya De Lucca nathysdlucca06@gmail.com inserida
# Gabriel Dantas gabrieldantas376@gmail.com inserida
# Beatriz Eller beaeller@gmail.com já está cadastrada
# Leticia Herculana leticiaherculana@gmail.com inserida
# Lucas de Jesus lucasdejesus866@gmail.com já está cadastrada
# Lucas Fonteles lucasfonteles_@hotmail.com inserida
# Camila Hanjoura cs.hanjoura@gmail.com inserida
# Bruno Benedito brunosilva07b@gmail.com já está cadastrada
# Maria Clara Giner mcginercosta@gmail.com já está cadastrada
# Izabella Santos izabellaroberta@vivaldi.net inserida
# Vitória Lemes lemesvitoria0701@gmail.com inserida
# Talita Toledo talidominguestoledo@gmail.com já está cadastrada
# Pamella Castro pamella.neiva@hotmail.com inserida
# Luiza Couto luizacunhacouto@gmail.com já está cadastrada
# Geovana Rodrigues geovana.rodriguesdej@gmail.com inserida
# Isadora Lima Dos Santos isadoralima2702@gmail.com já está cadastrada
# Samantha de Lima samantha.lima31@gmail.com inserida
# Vanessa Almeida vanalmeida18@gmail.com inserida
# Ian Valente Rossignoli ianvalente123@gmail.com inserida
# Laís Assumpção allbuquerquelais@gmail.com já está cadastrada
# Giovanna Sanches gielisa_@hotmail.com já está cadastrada
# Aline Moura alinebritomoura@gmail.com já está cadastrada
# Ian Casalecchi Giersztajn iancasa1234@hotmail.com inserida
# Layla Rayny Ferreira Silva laylaraynyf@gmail.com inserida
# Renata Sanches rennatta.sanches@gmail.com inserida
# Emily Curbani emilycurbani1@gmail.com inserida
# Guilherme Carvalho guilhermetcarvalho08@gmail.com inserida
# Renan Corazza renancorazza.c@gmail.com inserida
# Bianca Almeida bia.acc15@gmail.com inserida
# Paloma Bueno palomabuenori@gmail.com inserida

# %%
len(df_inseridos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(df_inseridos)
#
# NameError: name 'df_inseridos' is not defined

# %%
df_podio[df_podio['Email Limpo'] == 'fhod74rodrigues@hotmail.com']
# Out:
# Empty DataFrame
# Columns: [Nome, Data inscrição, produto, Duracao, Data de nascimento, [EXPA] EP ID, Email, Telefone, [INTERNO] Status, Realocação, CL que veio o lead realocado, Data de realocação, Desistência, [EXPA] Status, Curso, Experiências, Nível de inglês, Data de abordagem, Tempo de abordagem, EP Manager, [EXPA] Data doApplied, [EXPA] Data do Accepted, [EXPA] OP, [EXPA] Data do APD, Process Time, [EXPA] Application ID 1, tag-origem, tag-conteudo, tag-meio, universidade, gostaria-de-ser-contactado-por-celular, Interno, Anos Experiencia, Email Limpo]
# Index: []
#
# [0 rows x 34 columns]

# %%
import os
d_path = '../downloads/'
files = os.listdir(d_path)
for antigo, novo in [(x, f"{str((int(x.split('_')[0])-1)).zfill(3)}_{'Victor_Haruo.pdf' if i == 0 else '_'.join(files[i-1].split('_')[1:])}") for i, x in enumerate(files)]:
    os.rename(d_path+antigo, d_path+novo)
# Out:
# O Kernel falhou ao executar o código na célula atual ou em uma célula anterior. Examine o código nas células para identificar uma possível causa da falha. Clique <a href="https://aka.ms/vscodeJupyterKernelCrash">aqui</a> para obter mais informações. Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
